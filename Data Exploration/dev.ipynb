# %%
from web3 import Web3
import requests
import json
from pprint import pprint

# Connect to Ethereum node
web3 = Web3(Web3.HTTPProvider('https://mainnet.infura.io/v3/58ea22f2caa14187bd2b8c0682c84848'))

ETHERSCAN_API_KEY = "6AMB9PGBYJ5AHHCZHCCZAU5Y7E4KEVET47"

# %%
############################### Start definitions ###############################

class TransactionHandler:
    def __init__(self):
        pass

    def get_contract_name(self, contract_address: str) -> str or None:
        """
        Arguements:
            contract_address: contract address of smart contract to find name of
        Returns:
            String value of contracts name if available OR None if name is not available
        Notes:
            Calls Etherscan's source code API endpoint to find the smart contract's name
        """
        # Get contract name from source code
        source_code_endpoint = f"https://api.etherscan.io/api?module=contract&action=getsourcecode&address={contract_address}&apikey={ETHERSCAN_API_KEY}"
        source_code = json.loads(requests.get(source_code_endpoint).text)
        try:
            return source_code["result"][0]["ContractName"]
        except (KeyError, TypeError):
            return None

    def get_transaction_type(self, tx: str or dict) -> str:
        """
        Arguements:
            tx: Tx hash (str) OR Tx object (dict)
        Returns:
            String value representing type of transaction
        """
        # If 'tx' arguement is a transaction hash, get transaction object
        if isinstance(tx, str):
            tx = web3.eth.get_transaction(tx)
        # If "input" is not empty ('0x0'), "to" is not empty and "value" is equal to 0 -> smart contract transaction
        if tx["input"] != "0x" and tx["to"] != None and tx["value"] == 0:
            return "contract_invoked"
        # If "input" is empty ('0x') and "value" is not equal to 0 -> wallet-to-wallet transaction
        elif tx["input"] == "0x" and tx["value"] != 0:
            return "wallet_to_wallet"
        # If "to" is empty and "value" is equal to 0 -> contract creation transaction
        elif tx["to"] == None and tx["value"] == 0:
            return "contract_creation"
        else:
            raise RuntimeError(f"Unknown transaction type found for {tx['hash']}")

    def decode_transaction_input(self, tx: str or dict) -> dict:
        """
        Arguements:
            tx_input: Raw input data from transaction. 
            contract_address: Smart contract address. Use the "to" address on an Ethereum transaction.
        Returns:
            Dictionary containing the smart contract function's name, arguments and transaction parameters.
        Notes:
            Can only decode transactions with transaction type 'contract_invoked' returned by get_transaction_type()
        """
        # If 'tx' arguement is a transaction hash, get transaction object
        if isinstance(tx, str):
            tx = web3.eth.get_transaction(tx)
        # Check for supported transaction type
        if self.get_transaction_type(tx) != "contract_invoked":
            raise RuntimeError(f"Cannot parse input of transaction with type '{self.get_transaction_type(tx)}'.")
        # Get ABI for smart contract NOTE: Use "to" address as smart contract 'interacted with'
        abi_endpoint = f"https://api.etherscan.io/api?module=contract&action=getabi&address={tx['to']}&apikey={ETHERSCAN_API_KEY}"
        abi = json.loads(requests.get(abi_endpoint).text)
        # If Etherscan API returns 'Contract source code not verified', raise error
        if abi["result"] == "Contract source code not verified":
            raise RuntimeError(f"{abi['result']}. Recommended to hard-code the ABI of this smart contract address {tx['to']}.")
        # Create contract object in web3
        contract = web3.eth.contract(address=tx["to"], abi=abi["result"])
        # Decode transaction input data using Contract object's decode_function_input() method
        func_obj, func_params = contract.decode_function_input(tx["input"])
        return {
            "func_name": func_obj.fn_name,
            "args": tuple(func_params.keys()),
            "params": tuple(func_params.values()),
        }

############################### End definitions ###############################

# %%
# Tx hash's of different tx types
token_swap = "0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b" # "value" == 0, "to"/"from"/"input" are not empty
wallet_to_wallet = "0xc46bfff90f8a55a1037f62ab3183bc840b3e7eff6f84a0b6e142f849ee4b20be" # "input" is empty ('0x'), "value" != 0
contract_creation = "0x4ff39eceee7ba9a63736eae38be69b10347975ff5fa4d9b85743a51e1c384094" # "to" is empty ('0x0' or 'None'), "value" == 0, "input" is bytecode

# Instantiate transaction handler
th = TransactionHandler()

# %%
tx = web3.eth.get_transaction(token_swap)
tx
# Out:
# AttributeDict({'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#  'blockNumber': 12674755,
#  'from': '0x43CC25B1fB6435d8d893fCf308de5C300a568BE2',
#  'gas': 1402911,
#  'gasPrice': 122000000000,
#  'hash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#  'input': '...',
#  'nonce': 11974,
#  'r': HexBytes('0x649acf223ea61e4598280adc086f9a3d8a96e7cfc941f25c38d4bf29c3f77484'),
#  's': HexBytes('0x66fb1ee9861d4934810055a9d0f8eb15ebb19eee3225d6482bb548b5fa6e11aa'),
#  'to': '0xd9e1cE17f2641f24aE83637ab66a2cca9C378B9F',
#  'transactionIndex': 0,
#  'type': '0x0',
#  'v': 37,
#  'value': 0})

# %%
# Get transaction receipt
receipt = web3.eth.get_transaction_receipt(token_swap)
receipt
# Out:
# AttributeDict({'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#  'blockNumber': 12674755,
#  'contractAddress': None,
#  'cumulativeGasUsed': 121865,
#  'from': '0x43CC25B1fB6435d8d893fCf308de5C300a568BE2',
#  'gasUsed': 121865,
#  'logs': [AttributeDict({'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2',
#    'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#    'blockNumber': 12674755,
#    'data': '0x0000000000000000000000000000000000000000000000003a395039b420f1bd',
#    'logIndex': 0,
#    'removed': False,
#    'topics': [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'),
#     HexBytes('0x00000000000000000000000043cc25b1fb6435d8d893fcf308de5c300a568be2'),
#     HexBytes('0x00000000000000000000000044d34985826578e5ba24ec78c93be968549bb918')],
#    'transactionHash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#    'transactionIndex': 0}),
#   AttributeDict({'address': '0x3c9d6c1C73b31c837832c72E04D3152f051fc1A9',
#    'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#    'blockNumber': 12674755,
#    'data': '0x000000000000000000000000000000000000000000000001158e460913d00000',
#    'logIndex': 1,
#    'removed': False,
#    'topics': [HexBytes('0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef'),
#     HexBytes('0x00000000000000000000000044d34985826578e5ba24ec78c93be968549bb918'),
#     HexBytes('0x0000000000000000000000009a7ed54b8c2c5816c1800476f5111a1e88657502')],
#    'transactionHash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#    'transactionIndex': 0}),
#   AttributeDict({'address': '0x44D34985826578e5ba24ec78c93bE968549BB918',
#    'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#    'blockNumber': 12674755,
#    'data': '0x000000000000000000000000000000000000000000000021cf49a1bd840bd9630000000000000000000000000000000000000000000000074c6d9748b5e996d8',
#    'logIndex': 2,
#    'removed': False,
#    'topics': [HexBytes('0x1c411e9a96e071241c2f21f7726b17ae89e3cab4c78be50e062b03a9fffbbad1')],
#    'transactionHash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#    'transactionIndex': 0}),
#   AttributeDict({'address': '0x44D34985826578e5ba24ec78c93bE968549BB918',
#    'blockHash': HexBytes('0xa495e3d87cf01430e9838341e1d36929fc9c8dfdb89133b372cae4019b5a534a'),
#    'blockNumber': 12674755,
#    'data': '',
#    'logIndex': 3,
#    'removed': False,
#    'topics': [HexBytes('0xd78ad95fa46c994b6551d0da85fc275fe613ce37657fb8d5e3d130840159d822'),
#     HexBytes('0x000000000000000000000000d9e1ce17f2641f24ae83637ab66a2cca9c378b9f'),
#     HexBytes('0x0000000000000000000000009a7ed54b8c2c5816c1800476f5111a1e88657502')],
#    'transactionHash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#    'transactionIndex': 0})],
#  'logsBloom': HexBytes('...'),
#  'status': 1,
#  'to': '0xd9e1cE17f2641f24aE83637ab66a2cca9C378B9F',
#  'transactionHash': HexBytes('0xac80bab0940f061e184b0dda380d994e6fc14ab5d0c6f689035631c81bfe220b'),
#  'transactionIndex': 0,
#  'type': '0x0'})

# %%
# Get raw block
block = web3.eth.get_block("latest")
block
# Out:
# AttributeDict({'difficulty': 6757105048576577,
#  'extraData': HexBytes('0x426162656c20687a38'),
#  'gasLimit': 15014632,
#  'gasUsed': 15010393,
#  'hash': HexBytes('0x220c6c1f55e7f8bbe7c267eba96a3043b401cf40c2730b326629f2c2888c568c'),
#  'logsBloom': HexBytes('...'),
#  'miner': '0xB3b7874F13387D44a3398D298B075B7A3505D8d4',
#  'mixHash': HexBytes('0x23ea57e01a3da8f70e5334ee5970d09018cc6c4a162afce080bd2dc08a209d1f'),
#  'nonce': HexBytes('0x593f90c45a1576d0'),
#  'number': 12677940,
#  'parentHash': HexBytes('0xeaf599f4f5f9a95cdfb762bf29e086ae9386fa01c24a156d96d0033befc2f3a2'),
#  'receiptsRoot': HexBytes('0xa5c44b015f7ed92df2dfdd31b92251bd089bec82cabaa4d72797f3ff50ae1560'),
#  'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'),
#  'size': 61558,
#  'stateRoot': HexBytes('0xe5cda80f39f73eb086670a8938d82638515561fe0b97657f4ae8e552e886e2e7'),
#  'timestamp': 1624282740,
#  'totalDifficulty': 26561491504383552717580,
#  'transactions': [HexBytes('0x0cee9036dfeadbcd546f9cfbb134d68ea1cdadf7ec80d7d401d2e3a467366a52'),
#   HexBytes('0x00fbdd3ba932cf5c39b01540e4be2df6f9c25fd3526183b293da3e239acf3b03'),
#   HexBytes('0xd8242693f0ab8dabec17df72c8afdbcc79f16462a2a1575c3c3c301f34c1e1cc'),
#   HexBytes('0x3d4d77e43420e38efda711920d801c85b2f83cbb780c4fc29403b39eec21a85d'),
#   HexBytes('0x3afde77193fdd43964b46089ca4ee0a140647d05356ae9b0abb31b0277cc13c8'),
#   HexBytes('0x18792b7a99b89d9d6d5bfff56bc801716c735998207b7dee2f0be042b5f8f34f'),
#   HexBytes('0x5ee435675cb486ecd2513a3e0373667efbfbe4b26f57fdf62189bf03be6f2c3f'),
#   HexBytes('0xaa9b6ac94a1d4024927ca80104906bcd151f3ac9ac7f136a16cd4fcc1286c7bf'),
#   HexBytes('0x749cda6ebb2081e473951bbee0198460a25cca2144735c32cd013c6e52d3606d'),
#   HexBytes('0x683bb6f3f078a638028a14157382ae7d08873a08a8fbd169de5a67e2e834dce1'),
#   HexBytes('0xcb2a6b713f6f5aadd6486281b4237a4b4724fcd0306eec49e9834527e72fdc16'),
#   HexBytes('0xe6d0ca47a05e924c204337ad4447f9a4c4e0d8cf74b680292ad0823932bfbe01'),
#   HexBytes('0x498cc66ebc908712e8dd50ad65d0210e2cf858ca1e8b1a28e87ff4d317fa3930'),
#   HexBytes('0xfa2efb3ac42ed444b8aa10deab28d7afeb2acf403cf2e24c514a8e78b4c58958'),
#   HexBytes('0xe773ef98445922b9997e1545b02d022d3645d1dcfe8cb72995c8967d1fab116d'),
#   HexBytes('0xde3cd1192c33552e36ca54334a3b0c2a41a69556fd00d38ab6c9b988fa231fc9'),
#   HexBytes('0x8f481d98240f3804edd3e2a4666c28e1bf2c6e81584bd7deb2c3ad4ddfed3442'),
#   HexBytes('0x397f0abbafb04e4f83c1cb61d3c2383c4629791f6ebfcfe1f9537e097f03c46a'),
#   HexBytes('0x6c126d1b24958b4d10b583ba4ab546f410f7c98b74340a40010404cdd98d10fe'),
#   HexBytes('0x572a7551625e7ed6b3aac05aeb04eec7745754f366750ed107a6b1b7daef7155'),
#   HexBytes('0x7f9a551a0e53ba87f29bf4c785138364822b41f31a8aaa63db131d227494849c'),
#   HexBytes('0x4e422791da671a3860c8fc7e8adad0ee781333ab358271738b2580a86b6bf5db'),
#   HexBytes('0x262823d56e3c6d35d73236392f6600d39d80375f3b97afb50ce94436469a969e'),
#   HexBytes('0x8c270533f5f5591f25494936bd409b2aacd50ed59aa58bc1487d5540239fe585'),
#   HexBytes('0x0fab636d6e752af2f455b8562f98732a8fc93591041c27b4081d8008758deb49'),
#   HexBytes('0x3b54c8e67af9dcb3d203a500351c64ea7d54c69e49cf2eb3f87c6e6c3744b0aa'),
#   HexBytes('0x8e54eaa937a65d0c4985c824d4302b35d66c8fa9ce9f6f4abff066fe07b73782'),
#   HexBytes('0xa667cb65f419f2926fca60469107b3668d7546df7308817261b078e4e3dedb87'),
#   HexBytes('0xcbd29c5930b386148ff17b5390863c74a88944b75bf93565846a19243efba13f'),
#   HexBytes('0x9f48757d865e90e5cc24efc1aa6033f1f9cf1c43d85e1f60643b1908456579f0'),
#   HexBytes('0xcdab9eca4412bbec5ff9997153e656c05343c6305c05f2ce57583c85f0c74663'),
#   HexBytes('0x1d2149410ba5bd77cf6b3ad1e4d5faea7858fe34c35ef1bd6490223646667cd8'),
#   HexBytes('0x60ff25e3ffea7111dc5a3c5e9fbd43bf5e6fb56f78e2f8aa000e3490f1042155'),
#   HexBytes('0x44a266c0148e98e120e0bc291b6a0cb4e19ad99c17fdb93d3933d429ccf87fec'),
#   HexBytes('0x7e53f57dcf70b2551af141300cda8091ccfe373be435620f3fe59604c7a09c5c'),
#   HexBytes('0xea5c49855057bba5eb7d7161f71a7a1dc7ec2030e0a774ce4e8a43693db9b4a8'),
#   HexBytes('0x139d69d58598d0f06c982e61eff32e4a5a3683cf76a1c1fbb92e68184ee780cb'),
#   HexBytes('0xb659433fb40bf994f2de8725408f5e31ffd2a55fcf95bb74acae7448511e2089'),
#   HexBytes('0x1ed1cb212e4301d11a4721c7e180e13e607402d562eaa090f924b53f5be05fb9'),
#   HexBytes('0x438ee2397665d42b384a91a1191156d447304677f4f83e5e610db25c33fae495'),
#   HexBytes('0xb7d51b464dd15734763e404da8943a0f516056be35c7a5dd526e6e72d3471515'),
#   HexBytes('0x3452f8063fa6b48268a3a7fbe7a0e0e05d20e02222f14d000c216533547a6d01'),
#   HexBytes('0x81c6933442c4f5458b6ea6988e41cbd2844b3924db77bd6c820f683793a3c489'),
#   HexBytes('0x02521887a16f7755d3a8404d2155e8e659aaa7aa6e7df164052117609b754580'),
#   HexBytes('0xf0a918632709cf0c8ca97b416749011f5320dfffcfcef7233932e2df4b7547fa'),
#   HexBytes('0xff2aac3784e4cb7138713b2fa34bc095d798a0d0d1444a3b799c929ec65a5d38'),
#   HexBytes('0x6bd8fcdfd1b61e6c57e66aea9fcabd51167dcc4a798e4cd85e0ecd9608f4a347'),
#   HexBytes('0x56f3497f8a6e3cf8ebcbbd44c0a81abc98759a6053a8ddeb628738ca892c250d'),
#   HexBytes('0x3a3bc3f2c99082cbf2b2b1d14623f9e0bb2fa0b81680d72601b8824503f62df6'),
#   HexBytes('0xe2685043d3209c1bc7acc0f7e97096d29bc7196fed9e48fdfd60ffdc183358be'),
#   HexBytes('0x2f38bd090bcb4fea7d690b8163d837dfa2faa9f5b50a5f6ecd5f9b385785f48c'),
#   HexBytes('0xed18fc5024fdc6c8e7f7d8d36b12596a590f151514f881dd6f3e731fad215f75'),
#   HexBytes('0xa3df68a79025b0b81836c9b184195eb37ddc4a37c75a4394d29095f110f9002e'),
#   HexBytes('0x915435e623b195f3ca6ed08ecc4e86a978efd05f0a6f19782023e26aa55f2710'),
#   HexBytes('0x999e221a390fd3b115b03dbfa16033415e4815c2d568622e5079fbb08b8cd5a2'),
#   HexBytes('0x9ad8abe2dfdf401f10fd750d4482ed5de4a2932525ec27379c07b72ff4ed65ca'),
#   HexBytes('0xd8d79efcdf183b5e47e4cbb787c5e134618efbe8aa1da3f0a3da71761d4adcba'),
#   HexBytes('0xdc8569967e3727207da74041b44c588360d355dc6ba9356d8edd44466db75031'),
#   HexBytes('0x562d260fb4fef8155f79dfea4d6702b6c82cab836d530cc89b39cc62e0e442b1'),
#   HexBytes('0xf2a362916b9bb74c330b72c4ad8f2695648179a2d57858102aed585d486ed51f'),
#   HexBytes('0xded1c79e864c96967e2dfaea99afb9cfb8ac7535bb0ee71c296643937ab0c152'),
#   HexBytes('0x0b75caeb2816aa674609304eb0b0d5ee10ee471c40fbd1d8fe9eb2dfcac3965f'),
#   HexBytes('0x8de43c1253f783008a223e9dd1d9f93872248188b0e8fbf8dc5ae73ccc72fde7'),
#   HexBytes('0xb0a841c7409acc1b429a6c4ea94fdef58e5c1ae108c2a579fb7dc2256686aad6'),
#   HexBytes('0xd595720e08b93ea47e99a5fc354b58b2001c768aafcb72f3cd71900258a20eb9'),
#   HexBytes('0x16b51c296078e5a75d73f2a8eadd3dff9ff0418a555f22b985ec57b71242eee2'),
#   HexBytes('0x15e5168c2c1ee8b0e6f40632d3b37d6e08f584e361b6e1c4d1e8d74e8da894c0'),
#   HexBytes('0xaebab844d891e41e013ec7b29b92ae10a7dc693c1a1fe8de858ab8a0bc045b47'),
#   HexBytes('0xafa5fe1b2870214b21b21bbab3f6b9f4696a4ba617f39c22bd3b82af5b03b121'),
#   HexBytes('0x4650355abfec89811f8ac99917b85308aa6465df2f8db28ef6a4f220ab4d0be2'),
#   HexBytes('0xbca34ddc124dedd29e0986c19d6aa672e2dbeedb7865ae70c0c986f650e6946b'),
#   HexBytes('0x0be5d7a769a0def9ee85c580ae4d89bc00f6ae17ac5a0cab6b5d8475470ccd37'),
#   HexBytes('0x2618b8bea5433b4765d1ef0207dc56a1102e515c22b514a5a43f2f9a83744e91'),
#   HexBytes('0x4ded61c7c6f95b74505a1224855899c321785e0c8091aa96aa5cfde4c7550674'),
#   HexBytes('0x16bdc18818d0a0f9ef515159e27c2477b16188bad422aea033ebe2022a610cb2'),
#   HexBytes('0x48b060830f181db6c1261b07747c31ac66f81657ec96f7b03009f35e5f096f2d'),
#   HexBytes('0x398d6942861b08b6e44d9adc1d8dc0e2a2ddac3e6d4787e9f7331a9363cc3d96'),
#   HexBytes('0xfc5d6d15157408b0604a18687f2d568ed865aaf65a924e2b1f497fd93fc561ac'),
#   HexBytes('0x3a04f78282f4afc4d3afd89533301053d0aea0f57e27384d184ee2ad42a84f97'),
#   HexBytes('0xe8265eb02203497717c6e44c85d293341235def88c2bb778370cf510f8a081e1'),
#   HexBytes('0xa0d5bcca8025775669e48973d60e23e04f1603231533182b995c810ac5d24b36'),
#   HexBytes('0xe843c64423e55a13ead403003fcaa857d654322cd20c82ee518b3456f5d9e1a4'),
#   HexBytes('0x34c3ae83d1304fe8380dc0ef332ed97ceea04fcac2e335310b8031c213408915'),
#   HexBytes('0xfcafcee2430cbaf8b0cba64d7c24cbc1e6b6c0f66dfaaa628b32f322babbbf0e'),
#   HexBytes('0xbf53fc6ccd024b3444e1846b2362b14b0422e9dc1221fb2ccc5395c14fa20743'),
#   HexBytes('0x7be1741900de1032191436de0a9ae6bda6ce50c6722af7b2ead6c5e8e744e879'),
#   HexBytes('0xb6c17c90965e052c73acd48eea9f54451a14336912d43844336c015bb6984610'),
#   HexBytes('0x2b6a699f15f2e8f94e3905b3f04fd8d0ae9521a937fcc5d1555458522e27b52b'),
#   HexBytes('0xd3f0dcecfa8a65ad7320236e7b5c1e2a6cc8210411405da1c82201b1c555dadd'),
#   HexBytes('0xaf893a8483ca6070de77b008437f017f50d3bef427aaf7252f886d94faed5749'),
#   HexBytes('0xa66c352c019d3cefdc633677d9d097b5fea2bac85fd3b3a85ebfa1ff0eae8200'),
#   HexBytes('0x3d90e5a985d9e03a50e1a79e0ca4613383d7c6a17565ee959bff96c3cd2c72a5'),
#   HexBytes('0x4a49767df3975f88e2b3f02982300913b686efb5ee4f31993ee323ce2a0590f7'),
#   HexBytes('0xb9b762bdea2da7566665c109936da8f7a824986a8a44975488d1e4e5c0a981ed'),
#   HexBytes('0x8aaee8150fa7b51bcce30dcb049490f0aa43e0ed73e60045da4e84b2b0bc28c5'),
#   HexBytes('0xac06394e074bf6125adf2b73ba71fcc0857e1bcde69e65101e439e9d1027571d'),
#   HexBytes('0x241c7d4aa0d84d06d7487cc3f79efcb2e93f5b43b85929294e18e8d56f14b0d3'),
#   HexBytes('0x3d7185559304bab40ed3ddf77143531ec9ee41c0e62006b1560f6f801bb0d75e'),
#   HexBytes('0xf760db01e5fd33c15072f7b124163b55238ebc0bb91a4e72e518a8cb8edd9465'),
#   HexBytes('0x8b3db32c232a7400780453b817e98434c45b75ed0ce050eaa0cd00e29a88ea53'),
#   HexBytes('0x3ff005e836ae7e6b952f93c1665dcb38a06375009f14c1d7ca55d60ed8207606'),
#   HexBytes('0x943baa29e021060fc6c98d61fffa522a535b1ee43a23c80c4e5c60426c812344'),
#   HexBytes('0x29916e91eae2c8c814f5d91043c128ead99cefb8ec63147796ef9780d33d4479'),
#   HexBytes('0x3d20ec8ed054b61090032fc9281f52f3a3beec493f4dc933b02751295192868b'),
#   HexBytes('0x400e430fb465825d835446c549897c14ca3dba0873447a2ab55101303d2e2040'),
#   HexBytes('0xea3014a60a283973eb33a1521c4df50ff3b6d7d41fa6a805231aaca049e32b14'),
#   HexBytes('0xbc5a61df24af10bb1964f2241fca29658b8aa07fa5f1ce834f0ee79c697e4722'),
#   HexBytes('0x65d9ca071820cac523598eef94f2c80ff2d8ab108320721c40ff6444e28e5923'),
#   HexBytes('0x0a7d66658d144daa13ddbbeec1a2f91dbe74f4ab3f1dcaff943445c9ed398d08'),
#   HexBytes('0x6800d984edf863944a7dc399d8fd80e09e4327e2f776e0759daeb99bf59289c8'),
#   HexBytes('0xfffe206eae612dc717b09c30f859c316e7b5f76da77927540a2176a62b67a9d5'),
#   HexBytes('0xbd121f82a372805ddfefe27fa3ae1859fbc7b1dd31c221f34d6fa7a586be1edb'),
#   HexBytes('0x31bbb676a8223084b1a9a0bf6a58f018b1208af95b6c3b623dd39b17f7a6c394'),
#   HexBytes('0x29ad90ca3bd166b9b919cf25e542a560578bd2c3fe3e8d79058442c747f632c9'),
#   HexBytes('0x9243f13bd14d289b9ca3d391c96ef122443b3957ea16d9a0cfe574aab2d7ed79'),
#   HexBytes('0xecf1da73e110ef95281a22585fe61703b18e60fe9e94cc9defc1cf9f22826d37'),
#   HexBytes('0x9af58962115828cf666d4cd7946c2d5d4ef46167b65978be07bb0345d47b866a'),
#   HexBytes('0xf2c4dd81e0425dfe671f2f3354890d12e8e4dc0a41d89f1e516e9cad6fa3e96f'),
#   HexBytes('0xcc21a366142c964a1eb0c7020a4767dc1fb0a063fd904c6bb0036b174400da93'),
#   HexBytes('0xf33ee67847d103a3597de48b8fe385949c8193a89131d1ed76f29612dd2d5577'),
#   HexBytes('0xcf7c4e89f9351063851f753f94cbb797717d0b4b6f896793e330754649750c8d'),
#   HexBytes('0xac35c4ade827c6121da703da3c44fe74be4ee09b807bce2140346f4e053db433'),
#   HexBytes('0x45e0d91fe673292ef19f606750a01dcaa070c7618b5f9456d16bcff29100f535'),
#   HexBytes('0x2c96cec4ae497cc3e7acd01d0d63f3a5de29848830fab9d3dd654c5b33817848'),
#   HexBytes('0x36d46b66c79e4355cf37c07ccefb0f52983368d9ca15d09da1933f0aa59db3cb'),
#   HexBytes('0x8bd939f1abf28e0fdb2595756538b4d68b3d9d309456592513c19227b82f71e2'),
#   HexBytes('0x87848174a5c9091222617dd6d3407f46e3b1e66efa4acdeea0cb1c237be7295e'),
#   HexBytes('0xbff7bc1e8f4bf5710ef28eb9cfea123d38b5a415cec9636898db8cebafebe27c'),
#   HexBytes('0x79fec373e90527517ba9b406a010c44b9b6c829a374dd94e01270dc3320678cd'),
#   HexBytes('0x46be60ad70fd644a40f7b8aca2b5e6415429e6597c73aaadb780be29295808a3'),
#   HexBytes('0x44ea17d45e40a25aebf4913ff8e7b9709376ff50714144182abed1bd731b438c'),
#   HexBytes('0x30805450fee7a610671aa1bda67747f95f4d8ae1e18c681df6c967238fe6e87d'),
#   HexBytes('0xc17dd12c6c0f52e2517d1be63d81b66d7f045969e44e918fa50eebbd98c3c394'),
#   HexBytes('0xfcf91304eb2ad50d2d6d94a77a39e9dfd9d0b4b0dcac18a81036b916e240ada8'),
#   HexBytes('0x1effdddbe192d2313347052f0247c168fc1a2a31b44bc0be6f3379f263e1a0e7'),
#   HexBytes('0xc6414d3267a090e50149092737cd36b19222e237603414737ed8502f0bf8c9a6'),
#   HexBytes('0xb3fbce7a0412cded066d22b28477964dc38463520830cc80e183a6bc60469784'),
#   HexBytes('0xe6f69b48cd7026ff84694bf53a4f09eb31af65f7493407bc2d1b14a08071dc89'),
#   HexBytes('0x39a176c5af23661a3f8392cb4eb7b3e61ee40e40396861db5d3d1171aa46c1b3'),
#   HexBytes('0xc594ff38ee3bb22a216454d341c376edf41d6745f86175b331a1e29d74be4d65'),
#   HexBytes('0xd57caece56a5895f2d7dc6b51338cd8d05e6d4b419d99efa4aea5b02a8a0b864'),
#   HexBytes('0xbd2a1312a6997a6cacb77f3fbe9dfd93cd37e77e79d286cd7748fdee638e79c3'),
#   HexBytes('0x1947f91cd7e509ffcacc135a9638598dd8c6d81c6072945de8c0b14351d21b35'),
#   HexBytes('0x202c2b4a1f924735de0f0a39412815013b57fa96b836a1815756f164fad3f1c8'),
#   HexBytes('0x05d03c7930075ef818ba539d359e70054438ccf516f8957e31f5d0beccdea9de'),
#   HexBytes('0xfb9aedc6f087eb2d75e66884ff2b6370363e360f2bcf8cf3cc85b9a9521244c0'),
#   HexBytes('0x04b4e1b8797b529b98328b3a2e2bac626b143cf3ada830cd1c7d63f2da1d17c1'),
#   HexBytes('0x62d0ce96e62e39dfd240e9e0d7db6358ca67d9aa3746c4484544f706adba10fd'),
#   HexBytes('0x3be135b4add801ec26e0a2677fa2b456ad57c9b64a314f9b6fe3c642750a5aff'),
#   HexBytes('0x2dd290079cd69ad1269ff42c7cbe3e10052587e18f8fa9cacae7e17d12470e42'),
#   HexBytes('0x69ee5054e9a2f4a774c3b3c26cd6d68ea10e5bda172c53167dec638957a93153'),
#   HexBytes('0x667e2a48c291902c3b793bbdc20950e65aeb4d0ca83fa2dd676978eb6110cbe6'),
#   HexBytes('0x87ca477e1db1f8c1fafd5e66904db816d83034225c81a5fde7c0eda7ad1c0329'),
#   HexBytes('0x6e8eb5d9daddfe0a4e5f590f27c524cc322b1935530feae7f0e29fda49eb55e7'),
#   HexBytes('0xde28785c5e59a15322cd8534d8ca548ce75d421667348437a50abe381804686e'),
#   HexBytes('0x8933ea482cb68b154019425af1d15afd132cdc023e0adc6612ed482b2e34004b'),
#   HexBytes('0xfb3ec4dc9cdcb33c69cd7a43cfcdadf316ec1d9c69ceac0f817bbc21e2427dda'),
#   HexBytes('0xd4d94f152a8256b3dfbaada0238d8b21773fe68daf1e4c698b017abedead4ed9'),
#   HexBytes('0x1db9610d4b49f25d538f3acd83527cfff9d9c3ec12c308fd9970e763bf64c290'),
#   HexBytes('0x003fef82c1ef442523411aed3a550b7e371a532b48ff42bb5654939ed6136200'),
#   HexBytes('0xf99c92de7bc91fc294cae247c9759383d818bbdc2fcbed35cabfc0901e372a82'),
#   HexBytes('0x8ffeeaddb67f7258907307fbd4da851ea6eaaf1ed89783bd12eec894272ef44c'),
#   HexBytes('0x3747673f8907e0373fab73736befd5d64ac4fbfe3c553bed0749e91c986dac7c'),
#   HexBytes('0x7f083e6719338d08ae95591dd52656689537c75ddebffb05a60fd6e5e4b52df0'),
#   HexBytes('0x420e176fe6c55f3b1a450c7d60154805f285c4581d443eddcc8b67f8aabd55b8'),
#   HexBytes('0xb773e439dd2dcbb645350f7b4ff0750ba111877f0f96530ed5cb9eeb934fe122'),
#   HexBytes('0xcee7c3b4f240b88bde0e5aabef4368d69f068f6b47b1412f4f8c0e43b43f092f'),
#   HexBytes('0x143d376105ab972e5a90811dc72c869c809df4fc6bb452ba9e98c611b4c87b1e'),
#   HexBytes('0xf465a806c65b382c9870f91cbc0c441b654c683d6eca410fa96b23cbe218c7f9'),
#   HexBytes('0xec77d1a120baa1753e8126739551f4583a593173342511a32541d11be7e9d3f4'),
#   HexBytes('0xbb7c83b1135fb3c06eb1a16d60a1c3b0ee17c4cc89de0669dff45256a2ecf620'),
#   HexBytes('0x7b4dc8fe5b17f7d768411c7bcacf8afde7d60bb99b20196b930e41b27a4ed11a'),
#   HexBytes('0xad9bac70ebeb09ac0aa9edac26c78016b65c11f05e8f2734e99f269cb7cdba12'),
#   HexBytes('0xc79721abd7a776bb44f11f6696314e6f786b0136a34ab76aaec8de8f8fc285c9'),
#   HexBytes('0xd6b71c15a782df4b15edcdd2e6ab4b748fe8ec90a04b9df1342350b482524259')],
#  'transactionsRoot': HexBytes('0x6e0f439bafe2881f8f06174ab25bba823fd2c6260905cb046190df9899e71c77'),
#  'uncles': []})
